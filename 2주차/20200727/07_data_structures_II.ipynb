# %% [markdown]
# # 데이터 구조(Data Structure) II
#
# - 알고리즘에 빈번히 활용되는 순서가 없는(unordered) 데이터 구조
#     - 세트(Set)
#     - 딕셔너리(Dictionary)

# %% [markdown]
# # 세트(Set)
#
# > 변경 가능하고(mutable), 순서가 없고(unordered), 순회 가능한(iterable)
#
# 데이터 구조로서의 세트(set)와 조작법(method)

# %% [markdown]
# ## 추가 및 삭제
#
# ### `.add(elem)`
# elem을 세트에 추가합니다.

# %%
# add를 사용해봅시다.
a = {'사과', '바나나', '수박'}

# %%
#
a.add('포도')
a.add('포도')
print(a)
# Out:
# {'포도', '수박', '바나나', '사과'}

# %% [markdown]
# ### `.update(*others)`
#
# 여러가지의 값을 추가합니다.
#
# 인자로는 반드시 iterable 데이터 구조를 전달해야합니다.

# %%
# update를 사용해봅시다.
a = {'사과', '바나나', '수박'}

# %%
#
a.update({'토마토', '토마토', '딸기'}, {'포도', '레몬'})
print(a)
# Out:
# {'토마토', '포도', '수박', '바나나', '레몬', '딸기', '사과'}

# %% [markdown]
# ### `.remove(elem)`
#
# elem을 세트에서 삭제하고, 없으면 KeyError가 발생합니다.

# %%
# remove를 사용해봅시다.
a = {'사과', '바나나', '수박'}

# %%
#
a.remove('애플')
a.remove('사과')
print(a)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-e66075fb0330> in <module>()
#       1 #
# ----> 2 a.remove('애플')
#       3 a.remove('사과')
#       4 print(a)
#
# KeyError: '애플'

# %% [markdown]
# ### `.discard(elem)`
# elem을 세트에서 삭제하고 없어도 에러가 발생하지 않습니다.

# %%
# discard를 사용해봅시다.
a = {'사과', '바나나', '수박'}

# %%
#
a.discard('포도')
a.discard('수박')
print(a)
# Out:
# {'바나나', '사과'}

# %% [markdown]
# ### `.pop()`
#
# **임의의 원소**를 제거해 반환합니다.

# %%
# pop을 사용해봅시다.
a = {'사과', '바나나', '수박', '아보카도'}

# %%
#
print(a.pop())
print(a)
# Out:
# 수박
# {'바나나', '아보카도', '사과'}

# %% [markdown]
# # 딕셔너리(Dictionary)
#
# > 변경 가능하고(mutable), 순서가 없고(unordered), 순회 가능한(iterable)
# >
# > `Key: Value` 페어(pair)의 자료구조
#
# 데이터 구조로서의 딕셔너리(dictionary)와 조작법(method)

# %% [markdown]
# ## 조회

# %% [markdown]
# ### `.get(key[, default])`
#
# key를 통해 value를 가져옵니다.
#
# 절대로 KeyError가 발생하지 않습니다. default는 기본적으로 None입니다.

# %%
# get을 사용해봅시다.
my_dict = {'apple': '사과', 'banana': '바나나', 'melon': '멜론'}
my_dict['pineapple']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-d3cdd6ee6d26> in <module>()
#       1 # get을 사용해봅시다.
#       2 my_dict = {'apple': '사과', 'banana': '바나나', 'melon': '멜론'}
# ----> 3 my_dict['pineapple']
#
# KeyError: 'pineapple'

# %%
#
print(my_dict.get('pineapple'))
print(my_dict.get('apple'))
print(my_dict.get('pineapple', 0))
# Out:
# None
# 사과
# 0

# %% [markdown]
# ## 추가 및 삭제
#
# ### `.pop(key[, default])`
#
# key가 딕셔너리에 있으면 제거하고 그 값을 돌려줍니다. 그렇지 않으면 default를 반환합니다.
#
# default가 없는 상태에서 딕셔너리에 없으면 KeyError가 발생합니다.

# %%
# pop을 사용해봅시다.
my_dict = {'apple': '사과', 'banana': '바나나'}

# %%
#
my_dict.pop('apple')
print(my_dict)
# Out:
# {'banana': '바나나'}

# %%
# 딕셔너리에 없으면 에러가 발생합니다.

# %%
#
my_dict.pop('melon')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-13-3cf05de36274> in <module>()
#       1 #
# ----> 2 my_dict.pop('melon')
#
# KeyError: 'melon'

# %%
# 두번째 인자로 default를 설정할 수 있습니다.

# %%
#
my_dict.pop('melon', 0)
# Out:
# 0

# %% [markdown]
# ### `.update()`
#
# 값을 제공하는 key, value로 덮어씁니다.

# %%
# update를 사용해봅시다.
my_dict = {'apple': '사과', 'banana': '바나나', 'melon': '멜론'}

# %%
#
my_dict.update(apple='애플')
print(my_dict)
# Out:
# {'apple': '애플', 'banana': '바나나', 'melon': '멜론'}

# %% [markdown]
# ## 딕셔너리 순회(반복문 활용)
#
# 딕셔너리에 `for` 문을 실행하면 기본적으로 다음과 같이 동작합니다.

# %%
grades = {'john':  80, 'eric': 90, 'justin': 90}
for student in grades:
    print(student)
# Out:
# john
# eric
# justin

# %% [markdown]
# 딕셔너리의 **key**를 접근할 수 있으면 **value**에도 접근할 수 있기 때문입니다.
#
# 따라서 딕셔너리의 value를 출력하기 위해서는 아래와 같이 작성합니다.

# %%
# 학생 이름(key)을 활용하여 점수(value)를 출력해봅시다.

# %%
#
for student in grades:
    print(grades[student])
# Out:
# 80
# 90
# 90

# %% [markdown]
# * dictionary에서 `for`를 활용하는 4가지 방법
#
# ```python
# # 0. dictionary 순회 (key 활용)
# for key in dict:
#     print(key)
#     print(dict[key])
#
#
# # 1. `.keys()` 활용
# for key in dict.keys():
#     print(key)
#     print(dict[key])
#
#
# # 2. `.values()` 활용
# for val in dict.values():
#     print(val)
#
#
# # 3. `.items()` 활용
# for key, val in dict.items():
#     print(key, val)
#
# ```

# %% [markdown]
# ### [연습] 딕셔너리 순회
#
# > 혈액형 검사한 결과가 담긴 `blood_types`이 주어졌을때, 해당 딕셔너리를 순회하며, `key`와 `value`를 출력해보세요.
#
# ---
#
# **[출력 예시]**
# ```
# A형은 40명입니다.
# B형은 11명입니다.
# AB형은 4명입니다.
# O형은 45명입니다.
# ```

# %%
blood_types = {'A': 40, 'B': 11, 'AB': 4, 'O': 45}

# %%
# 아래에 코드를 작성하세요.

# %%
# key로 반복하는 코드를 작성해봅시다.

# %%
#
for i in blood_types:
  print(f'{i}형은 {blood_types[i]}명입니다.')
# Out:
# A형은 40명입니다.
# B형은 11명입니다.
# AB형은 4명입니다.
# O형은 45명입니다.

# %%
# .keys()를 활용하여 반복하는 코드를 작성해봅시다.

# %%
#
for i in blood_types.keys():
  print(f'{i}형은 {blood_types[i]}명입니다.')
# Out:
# A형은 40명입니다.
# B형은 11명입니다.
# AB형은 4명입니다.
# O형은 45명입니다.

# %%
# .items()를 활용하여 반복하는 코드를 작성해봅시다.

# %%
#
for i,j in blood_types.items():
  print(f'{i}형은 {j}명입니다.')
# Out:
# A형은 40명입니다.
# B형은 11명입니다.
# AB형은 4명입니다.
# O형은 45명입니다.

# %% [markdown]
# ### [실습] 딕셔너리 순회
#
# > 혈액형 검사한 결과가 담긴 `blood_types`이 주어졌을때, 해당 검사에 참가한 사람들의 총합을 구해보세요.
#
# ---
#
# **[출력 예시]**
# ```
# 검사에 참가한 사람은 총 100명입니다.
# ```

# %%
# key로 반복하는 코드를 작성해봅시다.

# %%
total = 0
for i in blood_types:
  total += blood_types[i]
print(f'검사에 참가한 사람은 총 {total}명입니다.')
# Out:
# 검사에 참가한 사람은 총 100명입니다.

# %%
# .values()를 활용하여 작성해봅시다.

# %%
total = 0
for i in blood_types.values():
  total += i
print(f'검사에 참가한 사람은 총 {total}명입니다.')
# Out:
# 검사에 참가한 사람은 총 100명입니다.

# %%
# 더 간단하게 구할 수도 있습니다.

# %%
print(f'검사에 참가한 사람은 총 {sum(blood_types.values())}명입니다.')
# Out:
# 검사에 참가한 사람은 총 100명입니다.

# %% [markdown]
# ### [응용] 딕셔너리 구축하기(counter)
# > 리스트가 주어질 때, 각각의 요소의 개수를 value 값으로 갖는 딕셔너리를 만드세요.
#
# ---
#
# **[출력 예시]**
#
# {'great': 2, 'expectations': 1, 'the': 2, 'adventures': 2, 'of': 2, 'sherlock': 1, 'holmes': 1, 'gasby': 1, 'hamlet': 1, 'huckleberry': 1, 'fin': 1}

# %%
book_title =  ['great', 'expectations', 'the', 'adventures', 'of', 'sherlock', 'holmes', 'the', 'great', 'gasby', 'hamlet', 'adventures', 'of', 'huckleberry', 'fin']

# 아래에 코드를 작성하세요.

# %%
#
ret = {}
for i in book_title:
  if i in ret:
    ret[i] += 1
  else:
    ret[i] =1
print(ret)
# Out:
# {'great': 2, 'expectations': 1, 'the': 2, 'adventures': 2, 'of': 2, 'sherlock': 1, 'holmes': 1, 'gasby': 1, 'hamlet': 1, 'huckleberry': 1, 'fin': 1}

# %% [markdown]
# > `get(key[, default])`
# * key 가 딕셔너리에 있는 경우 key 에 대응하는 값을 돌려주고, 그렇지 않으면 default 를 돌려준다.

# %% [markdown]
# ## Dictionary comprehension
#
# dictionary도 comprehension을 활용하여 만들 수 있습니다.
#
# ---
#
# ### 활용법
# `iterable`에서 `dict`를 생성할 수 있습니다.
#
# ```python
# {키: 값 for 요소 in iterable}
#
# dict({키: 값 for 요소 in iterable})
# ```

# %%
# iterable(range) -> dict

# %%
#
cubic = {x: x**3 for x in range(1,4)}
print(cubic)
# Out:
# {1: 1, 2: 8, 3: 27}

# %%
# iterable(dict) -> dict

# %%
blood_types = {'A': 40, 'B': 11, 'AB': 4, 'O': 45}
negative_blood_types = {f'-{i}': j for i,j in blood_types.items()}
print(negative_blood_types)
# Out:
# {'-A': 40, '-B': 11, '-AB': 4, '-O': 45}

# %% [markdown]
# ## Dictionary comprehension + 조건
#
# List comprehension과 유사하게, 조건문에 참인 식으로 딕셔너리를 생성합니다.
#
#
# ### 활용법
#
# ```py
# {키: 값 for 요소 in iterable if 조건식}
#
# {키: 값 if 조건식 else 값 for 요소 in iterable}
#
# # elif 는 다음과 같이 사용해야 합니다. (if else 열거)
# {키: 값 if 조건식 else 식 if 조건식 else 식 if ... else ... for 변수 in iterable}
# ```

# %% [markdown]
# ### Dictionary comprehension 사용해보기

# %%
dusts = {'서울': 72, '대전': 82, '구미': 29, '광주': 45, '중국': 200}

# %%
# 미세먼지 농도가 80 초과 지역만 뽑아주세요.
# 예) {'대전': 82, '중국': 200}

# %%
#
result = {i:j for i,j in dusts.items() if j > 80}

# %%
print(result)
# Out:
# {'대전': 82, '중국': 200}

# %%
# 미세먼지 농도가 80초과는 나쁨 80이하는 보통으로 하는 value를 가지도록 바꾸세요.

# %%
#
result = {i: '나쁨' if j>80 else '보통' for i,j in dusts.items()}

# %%
print(result)
# Out:
# {'서울': '보통', '대전': '나쁨', '구미': '보통', '광주': '보통', '중국': '나쁨'}

# %%
# elif 도 사용할 수 있습니다. (if else 열거)

# %%
#
result = {}

# %%
print(result)
