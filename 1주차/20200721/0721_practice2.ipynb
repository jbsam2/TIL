# %% [markdown]
# # Practice 2
#
# > 데이터 & 제어문

# %% [markdown]
# ## 더블더블 (SWEA #2019 변형)
#
# > 자연수 number를 입력 받아, 1부터 주어진 자연수 number까지 홀수는 2, 짝수는 3을 곱한 값(들)을 출력하시오.
#
# ---
# ```
# [제약 사항]
# 주어질 숫자는 30을 넘지 않는다.
#
# [입력 예시]
# 5
#
# [출력 예시]
# 36
# ```

# %%
number = int(input())

# 아래에 코드를 작성하시오.
ans = 0
for i in range(1,number+1):
  if i % 2:
    ans += i*2
  else:
    ans += i*3
print(ans)
# Out:
# 5
# 36

# %% [markdown]
# ## 간단한 소수 판별 1
#
# > 입력으로 1개의 정수 number가 주어진다. 정수 number가 소수인지 아닌지 판별하여 출력하시오.
#
# ---
# ```
# [제약사항]
# number는 2이상 1,000이하의 정수이다. (2 ≤ number ≤ 1,000)
#
# [입력]
# 입력으로 정수 number가 주어진다.
#
# [출력]
# 정수 number가 소수이면 'Y', 소수가 아니면 'N'을 출력한다.
# ```

# %%
number = int(input())

# 아래에 코드를 작성하시오.
#1
i = 1
cnt = 0
while i <= number:
  if number % i == 0:
    cnt += 1
  i += 1
if cnt == 2:
  print('Y')
else:
  print('N')

#2
is_prime = 'Y'
for i in range(2, number):
  if number % i == 0:
    is_prime = 'N'
    break
print(is_prime)

#3
for i in range(2,number):
  if number % i == 0:
    print('N')
    break
else:
  print('Y')
# Out:
# 4
# N
# N
# N

# %% [markdown]
# ## 간단한 소수 판별 2
#
# > 조건, 반복문을 응용하여 numbers 리스트의 요소들이 소수인지 아닌지 판단하는 코드를 작성하시오.
#
# ---
# ```
# [출력 예시]
# 26은(는) 소수가 아닙니다. 2은(는) 26의 인수입니다.
# 39은(는) 소수가 아닙니다. 3은(는) 39의 인수입니다.
# 51은(는) 소수가 아닙니다. 3은(는) 51의 인수입니다.
# 53은(는) 소수입니다.
# 57은(는) 소수가 아닙니다. 3은(는) 57의 인수입니다.
# 79은(는) 소수입니다.
# 85은(는) 소수가 아닙니다. 5은(는) 85의 인수입니다.
# ```

# %%
numbers = [26, 39, 51, 53, 57, 79, 85]

# 아래에 코드를 작성하시오.

#1
for number in numbers:
  i = 1
  cnt = 0
  factor = 1
  while i <= number:
    if number % i == 0:
      if cnt == 1:
        factor = i
      cnt += 1
    i += 1
  if cnt == 2:
    print(f'{number}은(는) 소수입니다.')
  else:
    print(f'{number}은(는) 소수가 아닙니다. {factor}은(는) {number}의 인수입니다.')

#2
for number in numbers:
  is_prime = True
  factor
  for i in range(2, number):
    if number % i == 0:
      is_prime = False
      factor = i
      break
  if is_prime:
    print(f'{number}은(는) 소수입니다.')
  else:
    print(f'{number}은(는) 소수가 아닙니다. {factor}은(는) {number}의 인수입니다.')

#3
for number in numbers:
  is_prime = True
  factor
  for i in range(2, number):
    if number % i == 0:
      print(f'{number}은(는) 소수가 아닙니다. {factor}은(는) {number}의 인수입니다.')
      break
  else:
    print(f'{number}은(는) 소수입니다.')
# Out:
# 26은(는) 소수가 아닙니다. 2은(는) 26의 인수입니다.
# 39은(는) 소수가 아닙니다. 3은(는) 39의 인수입니다.
# 51은(는) 소수가 아닙니다. 3은(는) 51의 인수입니다.
# 53은(는) 소수입니다.
# 57은(는) 소수가 아닙니다. 3은(는) 57의 인수입니다.
# 79은(는) 소수입니다.
# 85은(는) 소수가 아닙니다. 5은(는) 85의 인수입니다.
# 26은(는) 소수가 아닙니다. 2은(는) 26의 인수입니다.
# 39은(는) 소수가 아닙니다. 3은(는) 39의 인수입니다.
# 51은(는) 소수가 아닙니다. 3은(는) 51의 인수입니다.
# 53은(는) 소수입니다.
# 57은(는) 소수가 아닙니다. 3은(는) 57의 인수입니다.
# 79은(는) 소수입니다.
# 85은(는) 소수가 아닙니다. 5은(는) 85의 인수입니다.
# 26은(는) 소수가 아닙니다. 5은(는) 26의 인수입니다.
# 39은(는) 소수가 아닙니다. 5은(는) 39의 인수입니다.
# 51은(는) 소수가 아닙니다. 5은(는) 51의 인수입니다.
# 53은(는) 소수입니다.
# 57은(는) 소수가 아닙니다. 5은(는) 57의 인수입니다.
# 79은(는) 소수입니다.
# 85은(는) 소수가 아닙니다. 5은(는) 85의 인수입니다.
